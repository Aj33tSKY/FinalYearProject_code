# %%
import cv2
import numpy as np
import os

input_dir = 'Test_Dataset/ColourTest3/Unstable/Before'
output_dir = 'Test_Dataset/ColourTest3/GTMasks'

os.makedirs(output_dir, exist_ok=True)

lower_red1 = np.array([0, 70, 50])
upper_red1 = np.array([10, 255, 255])
lower_red2 = np.array([170, 70, 50])
upper_red2 = np.array([180, 255, 255])

for filename in os.listdir(input_dir):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
     
        image_path = os.path.join(input_dir, filename)
        image = cv2.imread(image_path)

        hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

        mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
        mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
        red_mask = cv2.bitwise_or(mask1, mask2)

        kernel = np.ones((3, 3), np.uint8)
        red_mask = cv2.morphologyEx(red_mask, cv2.MORPH_OPEN, kernel)
        red_mask = cv2.morphologyEx(red_mask, cv2.MORPH_DILATE, kernel)

        mask_output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_mask.png")
        cv2.imwrite(mask_output_path, red_mask)

        print(f"Saved mask: {mask_output_path}")
# Out:
# Saved mask: Test_Dataset/ColourTest3/GTMasks\render_202_persp_left_before_mask.png
# Saved mask: Test_Dataset/ColourTest3/GTMasks\render_202_persp_right_before_mask.png
# Saved mask: Test_Dataset/ColourTest3/GTMasks\render_204_persp_left_before_mask.png
# Saved mask: Test_Dataset/ColourTest3/GTMasks\render_204_persp_right_before_mask.png
# Saved mask: Test_Dataset/ColourTest3/GTMasks\render_207_persp_left_before_mask.png
# Saved mask: Test_Dataset/ColourTest3/GTMasks\render_207_persp_right_before_mask.png
# Saved mask: Test_Dataset/ColourTest3/GTMasks\render_208_persp_left_before_mask.png
# Saved mask: Test_Dataset/ColourTest3/GTMasks\render_208_persp_right_before_mask.png
# Saved mask: Test_Dataset/ColourTest3/GTMasks\render_210_persp_left_before_mask.png
# Saved mask: Test_Dataset/ColourTest3/GTMasks\render_210_persp_right_before_mask.png
# Saved mask: Test_Dataset/ColourTest3/GTMasks\render_213_persp_left_before_mask.png
# ...
