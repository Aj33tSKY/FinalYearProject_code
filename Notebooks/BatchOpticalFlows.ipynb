# %%
import os
import glob
import torch
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import argparse
from RAFT.core.raft import RAFT
from RAFT.core.utils import flow_viz
from RAFT.core.utils.utils import InputPadder

DEVICE = 'cuda'

# %%
args = argparse.Namespace()
args.small = False
args.mixed_precision = True
args.alternate_corr = False

model = torch.nn.DataParallel(RAFT(args))
model.load_state_dict(torch.load("raft-things.pth"))
model = model.eval().cuda()

print("RAFT model loaded successfully!")

def load_image(imfile):
    img = Image.open(imfile).convert("RGB")
    img = np.array(img).astype(np.uint8)
    img = torch.from_numpy(img).permute(2, 0, 1).float()
    return img[None].to(DEVICE)

def flow_to_mask(flow, threshold):
    if flow.dim() == 4:
        flow = flow[0]
    flow_np = flow.cpu().numpy()
    u, v = flow_np[0], flow_np[1]
    magnitude = np.sqrt(u**2 + v**2)
    magnitude = (magnitude - magnitude.min()) / (magnitude.max() - magnitude.min() + 1e-8)
    mask = (magnitude > threshold).astype(np.uint8) * 255
    return mask

before_path = "Test_Dataset/Unstable/Before/*.png"
after_path = "Test_Dataset/Unstable/After/*.png"
motion_output_dir = "Test_Dataset/UnstableMotion/"

os.makedirs(motion_output_dir, exist_ok=True)

before_images = sorted(glob.glob(before_path))
after_images = sorted(glob.glob(after_path))

for before_img, after_img in zip(before_images, after_images):
    print(f"Processing: {before_img} and {after_img}")
    image1 = load_image(before_img)
    image2 = load_image(after_img)
    
    padder = InputPadder(image1.shape)
    image1, image2 = padder.pad(image1, image2)
    
    with torch.no_grad():
        _, flow_up = model(image1, image2, iters=20, test_mode=True)
    
    flow_up = padder.unpad(flow_up)
    mask = flow_to_mask(flow_up, threshold=0.2)
    
    mask_img = Image.fromarray(mask)
    output_filename = os.path.join(motion_output_dir, os.path.basename(after_img))
    mask_img.save(output_filename)
    
print("All optical flow masks have been processed and saved.")
# Out:
# C:\Users\ajeet\AppData\Local\Temp\ipykernel_27748\541396244.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("raft-things.pth"))
# RAFT model loaded successfully!
# Processing: Test_Dataset/Unstable/Before\render_00_before.png and Test_Dataset/Unstable/After\render_00_after.png
# Processing: Test_Dataset/Unstable/Before\render_03_before.png and Test_Dataset/Unstable/After\render_03_after.png
# Processing: Test_Dataset/Unstable/Before\render_04_before.png and Test_Dataset/Unstable/After\render_04_after.png
# Processing: Test_Dataset/Unstable/Before\render_06_before.png and Test_Dataset/Unstable/After\render_06_after.png
# Processing: Test_Dataset/Unstable/Before\render_07_before.png and Test_Dataset/Unstable/After\render_07_after.png
# Processing: Test_Dataset/Unstable/Before\render_08_before.png and Test_Dataset/Unstable/After\render_08_after.png
# Processing: Test_Dataset/Unstable/Before\render_101_before.png and Test_Dataset/Unstable/After\render_101_after.png
# Processing: Test_Dataset/Unstable/Before\render_102_before.png and Test_Dataset/Unstable/After\render_102_after.png
# Processing: Test_Dataset/Unstable/Before\render_105_before.png and Test_Dataset/Unstable/After\render_105_after.png
# Processing: Test_Dataset/Unstable/Before\render_112_before.png and Test_Dataset/Unstable/After\render_112_after.png
# Processing: Test_Dataset/Unstable/Before\render_115_before.png and Test_Dataset/Unstable/After\render_115_after.png
# Processing: Test_Dataset/Unstable/Before\render_116_before.png and Test_Dataset/Unstable/After\render_116_after.png
# Processing: Test_Dataset/Unstable/Before\render_117_before.png and Test_Dataset/Unstable/After\render_117_after.png
# Processing: Test_Dataset/Unstable/Before\render_119_before.png and Test_Dataset/Unstable/After\render_119_after.png
# Processing: Test_Dataset/Unstable/Before\render_11_before.png and Test_Dataset/Unstable/After\render_11_after.png
# Processing: Test_Dataset/Unstable/Before\render_122_before.png and Test_Dataset/Unstable/After\render_122_after.png
# Processing: Test_Dataset/Unstable/Before\render_124_before.png and Test_Dataset/Unstable/After\render_124_after.png
# Processing: Test_Dataset/Unstable/Before\render_125_before.png and Test_Dataset/Unstable/After\render_125_after.png
# Processing: Test_Dataset/Unstable/Before\render_126_before.png and Test_Dataset/Unstable/After\render_126_after.png
# Processing: Test_Dataset/Unstable/Before\render_127_before.png and Test_Dataset/Unstable/After\render_127_after.png
# Processing: Test_Dataset/Unstable/Before\render_12_before.png and Test_Dataset/Unstable/After\render_12_after.png
# Processing: Test_Dataset/Unstable/Before\render_132_before.png and Test_Dataset/Unstable/After\render_132_after.png
# Processing: Test_Dataset/Unstable/Before\render_134_before.png and Test_Dataset/Unstable/After\render_134_after.png
# Processing: Test_Dataset/Unstable/Before\render_135_before.png and Test_Dataset/Unstable/After\render_135_after.png
# Processing: Test_Dataset/Unstable/Before\render_136_before.png and Test_Dataset/Unstable/After\render_136_after.png
# Processing: Test_Dataset/Unstable/Before\render_137_before.png and Test_Dataset/Unstable/After\render_137_after.png
# Processing: Test_Dataset/Unstable/Before\render_138_before.png and Test_Dataset/Unstable/After\render_138_after.png
# Processing: Test_Dataset/Unstable/Before\render_139_before.png and Test_Dataset/Unstable/After\render_139_after.png
# Processing: Test_Dataset/Unstable/Before\render_13_before.png and Test_Dataset/Unstable/After\render_13_after.png
# Processing: Test_Dataset/Unstable/Before\render_140_before.png and Test_Dataset/Unstable/After\render_140_after.png
# Processing: Test_Dataset/Unstable/Before\render_141_before.png and Test_Dataset/Unstable/After\render_141_after.png
# Processing: Test_Dataset/Unstable/Before\render_142_before.png and Test_Dataset/Unstable/After\render_142_after.png
# Processing: Test_Dataset/Unstable/Before\render_143_before.png and Test_Dataset/Unstable/After\render_143_after.png
# Processing: Test_Dataset/Unstable/Before\render_145_before.png and Test_Dataset/Unstable/After\render_145_after.png
# Processing: Test_Dataset/Unstable/Before\render_147_before.png and Test_Dataset/Unstable/After\render_147_after.png
# Processing: Test_Dataset/Unstable/Before\render_148_before.png and Test_Dataset/Unstable/After\render_148_after.png
# Processing: Test_Dataset/Unstable/Before\render_149_before.png and Test_Dataset/Unstable/After\render_149_after.png
# Processing: Test_Dataset/Unstable/Before\render_14_before.png and Test_Dataset/Unstable/After\render_14_after.png
# Processing: Test_Dataset/Unstable/Before\render_151_before.png and Test_Dataset/Unstable/After\render_151_after.png
# Processing: Test_Dataset/Unstable/Before\render_153_before.png and Test_Dataset/Unstable/After\render_153_after.png
# Processing: Test_Dataset/Unstable/Before\render_154_before.png and Test_Dataset/Unstable/After\render_154_after.png
# Processing: Test_Dataset/Unstable/Before\render_156_before.png and Test_Dataset/Unstable/After\render_156_after.png
# Processing: Test_Dataset/Unstable/Before\render_157_before.png and Test_Dataset/Unstable/After\render_157_after.png
# Processing: Test_Dataset/Unstable/Before\render_159_before.png and Test_Dataset/Unstable/After\render_159_after.png
# Processing: Test_Dataset/Unstable/Before\render_162_before.png and Test_Dataset/Unstable/After\render_162_after.png
# Processing: Test_Dataset/Unstable/Before\render_163_before.png and Test_Dataset/Unstable/After\render_163_after.png
# Processing: Test_Dataset/Unstable/Before\render_164_before.png and Test_Dataset/Unstable/After\render_164_after.png
# Processing: Test_Dataset/Unstable/Before\render_166_before.png and Test_Dataset/Unstable/After\render_166_after.png
# Processing: Test_Dataset/Unstable/Before\render_169_before.png and Test_Dataset/Unstable/After\render_169_after.png
# Processing: Test_Dataset/Unstable/Before\render_170_before.png and Test_Dataset/Unstable/After\render_170_after.png
# Processing: Test_Dataset/Unstable/Before\render_171_before.png and Test_Dataset/Unstable/After\render_171_after.png
# Processing: Test_Dataset/Unstable/Before\render_172_before.png and Test_Dataset/Unstable/After\render_172_after.png
# Processing: Test_Dataset/Unstable/Before\render_174_before.png and Test_Dataset/Unstable/After\render_174_after.png
# Processing: Test_Dataset/Unstable/Before\render_177_before.png and Test_Dataset/Unstable/After\render_177_after.png
# Processing: Test_Dataset/Unstable/Before\render_178_before.png and Test_Dataset/Unstable/After\render_178_after.png
# Processing: Test_Dataset/Unstable/Before\render_179_before.png and Test_Dataset/Unstable/After\render_179_after.png
# Processing: Test_Dataset/Unstable/Before\render_17_before.png and Test_Dataset/Unstable/After\render_17_after.png
# Processing: Test_Dataset/Unstable/Before\render_180_before.png and Test_Dataset/Unstable/After\render_180_after.png
# Processing: Test_Dataset/Unstable/Before\render_181_before.png and Test_Dataset/Unstable/After\render_181_after.png
# Processing: Test_Dataset/Unstable/Before\render_182_before.png and Test_Dataset/Unstable/After\render_182_after.png
# Processing: Test_Dataset/Unstable/Before\render_183_before.png and Test_Dataset/Unstable/After\render_183_after.png
# Processing: Test_Dataset/Unstable/Before\render_202_before.png and Test_Dataset/Unstable/After\render_202_after.png
# Processing: Test_Dataset/Unstable/Before\render_203_before.png and Test_Dataset/Unstable/After\render_203_after.png
# Processing: Test_Dataset/Unstable/Before\render_204_before.png and Test_Dataset/Unstable/After\render_204_after.png
# Processing: Test_Dataset/Unstable/Before\render_205_before.png and Test_Dataset/Unstable/After\render_205_after.png
# Processing: Test_Dataset/Unstable/Before\render_206_before.png and Test_Dataset/Unstable/After\render_206_after.png
# Processing: Test_Dataset/Unstable/Before\render_207_before.png and Test_Dataset/Unstable/After\render_207_after.png
# Processing: Test_Dataset/Unstable/Before\render_208_before.png and Test_Dataset/Unstable/After\render_208_after.png
# Processing: Test_Dataset/Unstable/Before\render_20_before.png and Test_Dataset/Unstable/After\render_20_after.png
# Processing: Test_Dataset/Unstable/Before\render_211_before.png and Test_Dataset/Unstable/After\render_211_after.png
# Processing: Test_Dataset/Unstable/Before\render_212_before.png and Test_Dataset/Unstable/After\render_212_after.png
# Processing: Test_Dataset/Unstable/Before\render_213_before.png and Test_Dataset/Unstable/After\render_213_after.png
# Processing: Test_Dataset/Unstable/Before\render_214_before.png and Test_Dataset/Unstable/After\render_214_after.png
# Processing: Test_Dataset/Unstable/Before\render_216_before.png and Test_Dataset/Unstable/After\render_216_after.png
# Processing: Test_Dataset/Unstable/Before\render_217_before.png and Test_Dataset/Unstable/After\render_217_after.png
# Processing: Test_Dataset/Unstable/Before\render_218_before.png and Test_Dataset/Unstable/After\render_218_after.png
# Processing: Test_Dataset/Unstable/Before\render_220_before.png and Test_Dataset/Unstable/After\render_220_after.png
# Processing: Test_Dataset/Unstable/Before\render_221_before.png and Test_Dataset/Unstable/After\render_221_after.png
# Processing: Test_Dataset/Unstable/Before\render_222_before.png and Test_Dataset/Unstable/After\render_222_after.png
# Processing: Test_Dataset/Unstable/Before\render_223_before.png and Test_Dataset/Unstable/After\render_223_after.png
# Processing: Test_Dataset/Unstable/Before\render_225_before.png and Test_Dataset/Unstable/After\render_225_after.png
# Processing: Test_Dataset/Unstable/Before\render_227_before.png and Test_Dataset/Unstable/After\render_227_after.png
# Processing: Test_Dataset/Unstable/Before\render_228_before.png and Test_Dataset/Unstable/After\render_228_after.png
# Processing: Test_Dataset/Unstable/Before\render_229_before.png and Test_Dataset/Unstable/After\render_229_after.png
# Processing: Test_Dataset/Unstable/Before\render_22_before.png and Test_Dataset/Unstable/After\render_22_after.png
# Processing: Test_Dataset/Unstable/Before\render_230_before.png and Test_Dataset/Unstable/After\render_230_after.png
# Processing: Test_Dataset/Unstable/Before\render_231_before.png and Test_Dataset/Unstable/After\render_231_after.png
# Processing: Test_Dataset/Unstable/Before\render_233_before.png and Test_Dataset/Unstable/After\render_233_after.png
# Processing: Test_Dataset/Unstable/Before\render_235_before.png and Test_Dataset/Unstable/After\render_235_after.png
# Processing: Test_Dataset/Unstable/Before\render_236_before.png and Test_Dataset/Unstable/After\render_236_after.png
# Processing: Test_Dataset/Unstable/Before\render_238_before.png and Test_Dataset/Unstable/After\render_238_after.png
# Processing: Test_Dataset/Unstable/Before\render_239_before.png and Test_Dataset/Unstable/After\render_239_after.png
# Processing: Test_Dataset/Unstable/Before\render_23_before.png and Test_Dataset/Unstable/After\render_23_after.png
# Processing: Test_Dataset/Unstable/Before\render_240_before.png and Test_Dataset/Unstable/After\render_240_after.png
# Processing: Test_Dataset/Unstable/Before\render_241_before.png and Test_Dataset/Unstable/After\render_241_after.png
# Processing: Test_Dataset/Unstable/Before\render_242_before.png and Test_Dataset/Unstable/After\render_242_after.png
# Processing: Test_Dataset/Unstable/Before\render_243_before.png and Test_Dataset/Unstable/After\render_243_after.png
# Processing: Test_Dataset/Unstable/Before\render_244_before.png and Test_Dataset/Unstable/After\render_244_after.png
# Processing: Test_Dataset/Unstable/Before\render_245_before.png and Test_Dataset/Unstable/After\render_245_after.png
# Processing: Test_Dataset/Unstable/Before\render_246_before.png and Test_Dataset/Unstable/After\render_246_after.png
# Processing: Test_Dataset/Unstable/Before\render_249_before.png and Test_Dataset/Unstable/After\render_249_after.png
# Processing: Test_Dataset/Unstable/Before\render_24_before.png and Test_Dataset/Unstable/After\render_24_after.png
# Processing: Test_Dataset/Unstable/Before\render_250_before.png and Test_Dataset/Unstable/After\render_250_after.png
# Processing: Test_Dataset/Unstable/Before\render_251_before.png and Test_Dataset/Unstable/After\render_251_after.png
# Processing: Test_Dataset/Unstable/Before\render_252_before.png and Test_Dataset/Unstable/After\render_252_after.png
# Processing: Test_Dataset/Unstable/Before\render_254_before.png and Test_Dataset/Unstable/After\render_254_after.png
# Processing: Test_Dataset/Unstable/Before\render_255_before.png and Test_Dataset/Unstable/After\render_255_after.png
# Processing: Test_Dataset/Unstable/Before\render_257_before.png and Test_Dataset/Unstable/After\render_257_after.png
# Processing: Test_Dataset/Unstable/Before\render_258_before.png and Test_Dataset/Unstable/After\render_258_after.png
# Processing: Test_Dataset/Unstable/Before\render_259_before.png and Test_Dataset/Unstable/After\render_259_after.png
# Processing: Test_Dataset/Unstable/Before\render_25_before.png and Test_Dataset/Unstable/After\render_25_after.png
# Processing: Test_Dataset/Unstable/Before\render_261_before.png and Test_Dataset/Unstable/After\render_261_after.png
# Processing: Test_Dataset/Unstable/Before\render_262_before.png and Test_Dataset/Unstable/After\render_262_after.png
# Processing: Test_Dataset/Unstable/Before\render_265_before.png and Test_Dataset/Unstable/After\render_265_after.png
# Processing: Test_Dataset/Unstable/Before\render_266_before.png and Test_Dataset/Unstable/After\render_266_after.png
# Processing: Test_Dataset/Unstable/Before\render_267_before.png and Test_Dataset/Unstable/After\render_267_after.png
# Processing: Test_Dataset/Unstable/Before\render_268_before.png and Test_Dataset/Unstable/After\render_268_after.png
# Processing: Test_Dataset/Unstable/Before\render_269_before.png and Test_Dataset/Unstable/After\render_269_after.png
# Processing: Test_Dataset/Unstable/Before\render_270_before.png and Test_Dataset/Unstable/After\render_270_after.png
# Processing: Test_Dataset/Unstable/Before\render_273_before.png and Test_Dataset/Unstable/After\render_273_after.png
# Processing: Test_Dataset/Unstable/Before\render_274_before.png and Test_Dataset/Unstable/After\render_274_after.png
# Processing: Test_Dataset/Unstable/Before\render_275_before.png and Test_Dataset/Unstable/After\render_275_after.png
# Processing: Test_Dataset/Unstable/Before\render_276_before.png and Test_Dataset/Unstable/After\render_276_after.png
# Processing: Test_Dataset/Unstable/Before\render_278_before.png and Test_Dataset/Unstable/After\render_278_after.png
# Processing: Test_Dataset/Unstable/Before\render_279_before.png and Test_Dataset/Unstable/After\render_279_after.png
# Processing: Test_Dataset/Unstable/Before\render_27_before.png and Test_Dataset/Unstable/After\render_27_after.png
# Processing: Test_Dataset/Unstable/Before\render_283_before.png and Test_Dataset/Unstable/After\render_283_after.png
# Processing: Test_Dataset/Unstable/Before\render_284_before.png and Test_Dataset/Unstable/After\render_284_after.png
# Processing: Test_Dataset/Unstable/Before\render_288_before.png and Test_Dataset/Unstable/After\render_288_after.png
# Processing: Test_Dataset/Unstable/Before\render_289_before.png and Test_Dataset/Unstable/After\render_289_after.png
# Processing: Test_Dataset/Unstable/Before\render_28_before.png and Test_Dataset/Unstable/After\render_28_after.png
# Processing: Test_Dataset/Unstable/Before\render_290_before.png and Test_Dataset/Unstable/After\render_290_after.png
# Processing: Test_Dataset/Unstable/Before\render_294_before.png and Test_Dataset/Unstable/After\render_294_after.png
# Processing: Test_Dataset/Unstable/Before\render_298_before.png and Test_Dataset/Unstable/After\render_298_after.png
# Processing: Test_Dataset/Unstable/Before\render_29_before.png and Test_Dataset/Unstable/After\render_29_after.png
# Processing: Test_Dataset/Unstable/Before\render_302_before.png and Test_Dataset/Unstable/After\render_302_after.png
# Processing: Test_Dataset/Unstable/Before\render_303_before.png and Test_Dataset/Unstable/After\render_303_after.png
# Processing: Test_Dataset/Unstable/Before\render_304_before.png and Test_Dataset/Unstable/After\render_304_after.png
# Processing: Test_Dataset/Unstable/Before\render_307_before.png and Test_Dataset/Unstable/After\render_307_after.png
# Processing: Test_Dataset/Unstable/Before\render_309_before.png and Test_Dataset/Unstable/After\render_309_after.png
# Processing: Test_Dataset/Unstable/Before\render_311_before.png and Test_Dataset/Unstable/After\render_311_after.png
# Processing: Test_Dataset/Unstable/Before\render_314_before.png and Test_Dataset/Unstable/After\render_314_after.png
# Processing: Test_Dataset/Unstable/Before\render_315_before.png and Test_Dataset/Unstable/After\render_315_after.png
# Processing: Test_Dataset/Unstable/Before\render_316_before.png and Test_Dataset/Unstable/After\render_316_after.png
# Processing: Test_Dataset/Unstable/Before\render_317_before.png and Test_Dataset/Unstable/After\render_317_after.png
# Processing: Test_Dataset/Unstable/Before\render_318_before.png and Test_Dataset/Unstable/After\render_318_after.png
# Processing: Test_Dataset/Unstable/Before\render_319_before.png and Test_Dataset/Unstable/After\render_319_after.png
# Processing: Test_Dataset/Unstable/Before\render_321_before.png and Test_Dataset/Unstable/After\render_321_after.png
# Processing: Test_Dataset/Unstable/Before\render_322_before.png and Test_Dataset/Unstable/After\render_322_after.png
# Processing: Test_Dataset/Unstable/Before\render_323_before.png and Test_Dataset/Unstable/After\render_323_after.png
# Processing: Test_Dataset/Unstable/Before\render_324_before.png and Test_Dataset/Unstable/After\render_324_after.png
# Processing: Test_Dataset/Unstable/Before\render_327_before.png and Test_Dataset/Unstable/After\render_327_after.png
# Processing: Test_Dataset/Unstable/Before\render_329_before.png and Test_Dataset/Unstable/After\render_329_after.png
# Processing: Test_Dataset/Unstable/Before\render_32_before.png and Test_Dataset/Unstable/After\render_32_after.png
# Processing: Test_Dataset/Unstable/Before\render_332_before.png and Test_Dataset/Unstable/After\render_332_after.png
# Processing: Test_Dataset/Unstable/Before\render_334_before.png and Test_Dataset/Unstable/After\render_334_after.png
# Processing: Test_Dataset/Unstable/Before\render_335_before.png and Test_Dataset/Unstable/After\render_335_after.png
# Processing: Test_Dataset/Unstable/Before\render_336_before.png and Test_Dataset/Unstable/After\render_336_after.png
# Processing: Test_Dataset/Unstable/Before\render_337_before.png and Test_Dataset/Unstable/After\render_337_after.png
# Processing: Test_Dataset/Unstable/Before\render_339_before.png and Test_Dataset/Unstable/After\render_339_after.png
# Processing: Test_Dataset/Unstable/Before\render_33_before.png and Test_Dataset/Unstable/After\render_33_after.png
# Processing: Test_Dataset/Unstable/Before\render_340_before.png and Test_Dataset/Unstable/After\render_340_after.png
# Processing: Test_Dataset/Unstable/Before\render_341_before.png and Test_Dataset/Unstable/After\render_341_after.png
# Processing: Test_Dataset/Unstable/Before\render_342_before.png and Test_Dataset/Unstable/After\render_342_after.png
# Processing: Test_Dataset/Unstable/Before\render_344_before.png and Test_Dataset/Unstable/After\render_344_after.png
# Processing: Test_Dataset/Unstable/Before\render_345_before.png and Test_Dataset/Unstable/After\render_345_after.png
# Processing: Test_Dataset/Unstable/Before\render_346_before.png and Test_Dataset/Unstable/After\render_346_after.png
# Processing: Test_Dataset/Unstable/Before\render_347_before.png and Test_Dataset/Unstable/After\render_347_after.png
# Processing: Test_Dataset/Unstable/Before\render_348_before.png and Test_Dataset/Unstable/After\render_348_after.png
# Processing: Test_Dataset/Unstable/Before\render_349_before.png and Test_Dataset/Unstable/After\render_349_after.png
# Processing: Test_Dataset/Unstable/Before\render_34_before.png and Test_Dataset/Unstable/After\render_34_after.png
# Processing: Test_Dataset/Unstable/Before\render_351_before.png and Test_Dataset/Unstable/After\render_351_after.png
# Processing: Test_Dataset/Unstable/Before\render_353_before.png and Test_Dataset/Unstable/After\render_353_after.png
# Processing: Test_Dataset/Unstable/Before\render_354_before.png and Test_Dataset/Unstable/After\render_354_after.png
# Processing: Test_Dataset/Unstable/Before\render_355_before.png and Test_Dataset/Unstable/After\render_355_after.png
# Processing: Test_Dataset/Unstable/Before\render_356_before.png and Test_Dataset/Unstable/After\render_356_after.png
# Processing: Test_Dataset/Unstable/Before\render_358_before.png and Test_Dataset/Unstable/After\render_358_after.png
# Processing: Test_Dataset/Unstable/Before\render_359_before.png and Test_Dataset/Unstable/After\render_359_after.png
# Processing: Test_Dataset/Unstable/Before\render_35_before.png and Test_Dataset/Unstable/After\render_35_after.png
# Processing: Test_Dataset/Unstable/Before\render_360_before.png and Test_Dataset/Unstable/After\render_360_after.png
# Processing: Test_Dataset/Unstable/Before\render_361_before.png and Test_Dataset/Unstable/After\render_361_after.png
# Processing: Test_Dataset/Unstable/Before\render_363_before.png and Test_Dataset/Unstable/After\render_363_after.png
# Processing: Test_Dataset/Unstable/Before\render_364_before.png and Test_Dataset/Unstable/After\render_364_after.png
# Processing: Test_Dataset/Unstable/Before\render_365_before.png and Test_Dataset/Unstable/After\render_365_after.png
# Processing: Test_Dataset/Unstable/Before\render_366_before.png and Test_Dataset/Unstable/After\render_366_after.png
# Processing: Test_Dataset/Unstable/Before\render_371_before.png and Test_Dataset/Unstable/After\render_371_after.png
# Processing: Test_Dataset/Unstable/Before\render_372_before.png and Test_Dataset/Unstable/After\render_372_after.png
# Processing: Test_Dataset/Unstable/Before\render_374_before.png and Test_Dataset/Unstable/After\render_374_after.png
# Processing: Test_Dataset/Unstable/Before\render_376_before.png and Test_Dataset/Unstable/After\render_376_after.png
# Processing: Test_Dataset/Unstable/Before\render_378_before.png and Test_Dataset/Unstable/After\render_378_after.png
# Processing: Test_Dataset/Unstable/Before\render_379_before.png and Test_Dataset/Unstable/After\render_379_after.png
# Processing: Test_Dataset/Unstable/Before\render_37_before.png and Test_Dataset/Unstable/After\render_37_after.png
# Processing: Test_Dataset/Unstable/Before\render_380_before.png and Test_Dataset/Unstable/After\render_380_after.png
# Processing: Test_Dataset/Unstable/Before\render_381_before.png and Test_Dataset/Unstable/After\render_381_after.png
# Processing: Test_Dataset/Unstable/Before\render_383_before.png and Test_Dataset/Unstable/After\render_383_after.png
# Processing: Test_Dataset/Unstable/Before\render_384_before.png and Test_Dataset/Unstable/After\render_384_after.png
# Processing: Test_Dataset/Unstable/Before\render_385_before.png and Test_Dataset/Unstable/After\render_385_after.png
# Processing: Test_Dataset/Unstable/Before\render_386_before.png and Test_Dataset/Unstable/After\render_386_after.png
# Processing: Test_Dataset/Unstable/Before\render_387_before.png and Test_Dataset/Unstable/After\render_387_after.png
# Processing: Test_Dataset/Unstable/Before\render_388_before.png and Test_Dataset/Unstable/After\render_388_after.png
# Processing: Test_Dataset/Unstable/Before\render_389_before.png and Test_Dataset/Unstable/After\render_389_after.png
# Processing: Test_Dataset/Unstable/Before\render_390_before.png and Test_Dataset/Unstable/After\render_390_after.png
# Processing: Test_Dataset/Unstable/Before\render_392_before.png and Test_Dataset/Unstable/After\render_392_after.png
# Processing: Test_Dataset/Unstable/Before\render_393_before.png and Test_Dataset/Unstable/After\render_393_after.png
# Processing: Test_Dataset/Unstable/Before\render_395_before.png and Test_Dataset/Unstable/After\render_395_after.png
# Processing: Test_Dataset/Unstable/Before\render_396_before.png and Test_Dataset/Unstable/After\render_396_after.png
# Processing: Test_Dataset/Unstable/Before\render_398_before.png and Test_Dataset/Unstable/After\render_398_after.png
# Processing: Test_Dataset/Unstable/Before\render_400_before.png and Test_Dataset/Unstable/After\render_400_after.png
# Processing: Test_Dataset/Unstable/Before\render_403_before.png and Test_Dataset/Unstable/After\render_403_after.png
# Processing: Test_Dataset/Unstable/Before\render_408_before.png and Test_Dataset/Unstable/After\render_408_after.png
# Processing: Test_Dataset/Unstable/Before\render_409_before.png and Test_Dataset/Unstable/After\render_409_after.png
# Processing: Test_Dataset/Unstable/Before\render_40_before.png and Test_Dataset/Unstable/After\render_40_after.png
# Processing: Test_Dataset/Unstable/Before\render_410_before.png and Test_Dataset/Unstable/After\render_410_after.png
# Processing: Test_Dataset/Unstable/Before\render_411_before.png and Test_Dataset/Unstable/After\render_411_after.png
# Processing: Test_Dataset/Unstable/Before\render_413_before.png and Test_Dataset/Unstable/After\render_413_after.png
# Processing: Test_Dataset/Unstable/Before\render_416_before.png and Test_Dataset/Unstable/After\render_416_after.png
# Processing: Test_Dataset/Unstable/Before\render_41_before.png and Test_Dataset/Unstable/After\render_41_after.png
# Processing: Test_Dataset/Unstable/Before\render_421_before.png and Test_Dataset/Unstable/After\render_421_after.png
# Processing: Test_Dataset/Unstable/Before\render_425_before.png and Test_Dataset/Unstable/After\render_425_after.png
# Processing: Test_Dataset/Unstable/Before\render_426_before.png and Test_Dataset/Unstable/After\render_426_after.png
# Processing: Test_Dataset/Unstable/Before\render_427_before.png and Test_Dataset/Unstable/After\render_427_after.png
# Processing: Test_Dataset/Unstable/Before\render_42_before.png and Test_Dataset/Unstable/After\render_42_after.png
# Processing: Test_Dataset/Unstable/Before\render_430_before.png and Test_Dataset/Unstable/After\render_430_after.png
# Processing: Test_Dataset/Unstable/Before\render_432_before.png and Test_Dataset/Unstable/After\render_432_after.png
# Processing: Test_Dataset/Unstable/Before\render_433_before.png and Test_Dataset/Unstable/After\render_433_after.png
# Processing: Test_Dataset/Unstable/Before\render_434_before.png and Test_Dataset/Unstable/After\render_434_after.png
# Processing: Test_Dataset/Unstable/Before\render_436_before.png and Test_Dataset/Unstable/After\render_436_after.png
# Processing: Test_Dataset/Unstable/Before\render_437_before.png and Test_Dataset/Unstable/After\render_437_after.png
# Processing: Test_Dataset/Unstable/Before\render_438_before.png and Test_Dataset/Unstable/After\render_438_after.png
# Processing: Test_Dataset/Unstable/Before\render_439_before.png and Test_Dataset/Unstable/After\render_439_after.png
# Processing: Test_Dataset/Unstable/Before\render_43_before.png and Test_Dataset/Unstable/After\render_43_after.png
# Processing: Test_Dataset/Unstable/Before\render_440_before.png and Test_Dataset/Unstable/After\render_440_after.png
# Processing: Test_Dataset/Unstable/Before\render_441_before.png and Test_Dataset/Unstable/After\render_441_after.png
# Processing: Test_Dataset/Unstable/Before\render_442_before.png and Test_Dataset/Unstable/After\render_442_after.png
# Processing: Test_Dataset/Unstable/Before\render_443_before.png and Test_Dataset/Unstable/After\render_443_after.png
# Processing: Test_Dataset/Unstable/Before\render_445_before.png and Test_Dataset/Unstable/After\render_445_after.png
# Processing: Test_Dataset/Unstable/Before\render_446_before.png and Test_Dataset/Unstable/After\render_446_after.png
# Processing: Test_Dataset/Unstable/Before\render_447_before.png and Test_Dataset/Unstable/After\render_447_after.png
# Processing: Test_Dataset/Unstable/Before\render_449_before.png and Test_Dataset/Unstable/After\render_449_after.png
# Processing: Test_Dataset/Unstable/Before\render_450_before.png and Test_Dataset/Unstable/After\render_450_after.png
# Processing: Test_Dataset/Unstable/Before\render_452_before.png and Test_Dataset/Unstable/After\render_452_after.png
# Processing: Test_Dataset/Unstable/Before\render_454_before.png and Test_Dataset/Unstable/After\render_454_after.png
# Processing: Test_Dataset/Unstable/Before\render_457_before.png and Test_Dataset/Unstable/After\render_457_after.png
# Processing: Test_Dataset/Unstable/Before\render_458_before.png and Test_Dataset/Unstable/After\render_458_after.png
# Processing: Test_Dataset/Unstable/Before\render_45_before.png and Test_Dataset/Unstable/After\render_45_after.png
# Processing: Test_Dataset/Unstable/Before\render_461_before.png and Test_Dataset/Unstable/After\render_461_after.png
# Processing: Test_Dataset/Unstable/Before\render_462_before.png and Test_Dataset/Unstable/After\render_462_after.png
# Processing: Test_Dataset/Unstable/Before\render_463_before.png and Test_Dataset/Unstable/After\render_463_after.png
# Processing: Test_Dataset/Unstable/Before\render_464_before.png and Test_Dataset/Unstable/After\render_464_after.png
# Processing: Test_Dataset/Unstable/Before\render_465_before.png and Test_Dataset/Unstable/After\render_465_after.png
# Processing: Test_Dataset/Unstable/Before\render_466_before.png and Test_Dataset/Unstable/After\render_466_after.png
# Processing: Test_Dataset/Unstable/Before\render_469_before.png and Test_Dataset/Unstable/After\render_469_after.png
# Processing: Test_Dataset/Unstable/Before\render_46_before.png and Test_Dataset/Unstable/After\render_46_after.png
# Processing: Test_Dataset/Unstable/Before\render_470_before.png and Test_Dataset/Unstable/After\render_470_after.png
# Processing: Test_Dataset/Unstable/Before\render_471_before.png and Test_Dataset/Unstable/After\render_471_after.png
# Processing: Test_Dataset/Unstable/Before\render_472_before.png and Test_Dataset/Unstable/After\render_472_after.png
# Processing: Test_Dataset/Unstable/Before\render_473_before.png and Test_Dataset/Unstable/After\render_473_after.png
# Processing: Test_Dataset/Unstable/Before\render_477_before.png and Test_Dataset/Unstable/After\render_477_after.png
# Processing: Test_Dataset/Unstable/Before\render_478_before.png and Test_Dataset/Unstable/After\render_478_after.png
# Processing: Test_Dataset/Unstable/Before\render_479_before.png and Test_Dataset/Unstable/After\render_479_after.png
# Processing: Test_Dataset/Unstable/Before\render_47_before.png and Test_Dataset/Unstable/After\render_47_after.png
# Processing: Test_Dataset/Unstable/Before\render_480_before.png and Test_Dataset/Unstable/After\render_480_after.png
# Processing: Test_Dataset/Unstable/Before\render_481_before.png and Test_Dataset/Unstable/After\render_481_after.png
# Processing: Test_Dataset/Unstable/Before\render_482_before.png and Test_Dataset/Unstable/After\render_482_after.png
# Processing: Test_Dataset/Unstable/Before\render_484_before.png and Test_Dataset/Unstable/After\render_484_after.png
# Processing: Test_Dataset/Unstable/Before\render_485_before.png and Test_Dataset/Unstable/After\render_485_after.png
# Processing: Test_Dataset/Unstable/Before\render_486_before.png and Test_Dataset/Unstable/After\render_486_after.png
# Processing: Test_Dataset/Unstable/Before\render_487_before.png and Test_Dataset/Unstable/After\render_487_after.png
# Processing: Test_Dataset/Unstable/Before\render_488_before.png and Test_Dataset/Unstable/After\render_488_after.png
# Processing: Test_Dataset/Unstable/Before\render_489_before.png and Test_Dataset/Unstable/After\render_489_after.png
# Processing: Test_Dataset/Unstable/Before\render_48_before.png and Test_Dataset/Unstable/After\render_48_after.png
# Processing: Test_Dataset/Unstable/Before\render_490_before.png and Test_Dataset/Unstable/After\render_490_after.png
# Processing: Test_Dataset/Unstable/Before\render_492_before.png and Test_Dataset/Unstable/After\render_492_after.png
# Processing: Test_Dataset/Unstable/Before\render_493_before.png and Test_Dataset/Unstable/After\render_493_after.png
# Processing: Test_Dataset/Unstable/Before\render_495_before.png and Test_Dataset/Unstable/After\render_495_after.png
# Processing: Test_Dataset/Unstable/Before\render_496_before.png and Test_Dataset/Unstable/After\render_496_after.png
# Processing: Test_Dataset/Unstable/Before\render_498_before.png and Test_Dataset/Unstable/After\render_498_after.png
# Processing: Test_Dataset/Unstable/Before\render_499_before.png and Test_Dataset/Unstable/After\render_499_after.png
# Processing: Test_Dataset/Unstable/Before\render_49_before.png and Test_Dataset/Unstable/After\render_49_after.png
# Processing: Test_Dataset/Unstable/Before\render_500_before.png and Test_Dataset/Unstable/After\render_500_after.png
# Processing: Test_Dataset/Unstable/Before\render_501_before.png and Test_Dataset/Unstable/After\render_501_after.png
# Processing: Test_Dataset/Unstable/Before\render_504_before.png and Test_Dataset/Unstable/After\render_504_after.png
# Processing: Test_Dataset/Unstable/Before\render_507_before.png and Test_Dataset/Unstable/After\render_507_after.png
# Processing: Test_Dataset/Unstable/Before\render_509_before.png and Test_Dataset/Unstable/After\render_509_after.png
# Processing: Test_Dataset/Unstable/Before\render_50_before.png and Test_Dataset/Unstable/After\render_50_after.png
# Processing: Test_Dataset/Unstable/Before\render_511_before.png and Test_Dataset/Unstable/After\render_511_after.png
# Processing: Test_Dataset/Unstable/Before\render_512_before.png and Test_Dataset/Unstable/After\render_512_after.png
# Processing: Test_Dataset/Unstable/Before\render_514_before.png and Test_Dataset/Unstable/After\render_514_after.png
# Processing: Test_Dataset/Unstable/Before\render_515_before.png and Test_Dataset/Unstable/After\render_515_after.png
# Processing: Test_Dataset/Unstable/Before\render_516_before.png and Test_Dataset/Unstable/After\render_516_after.png
# Processing: Test_Dataset/Unstable/Before\render_517_before.png and Test_Dataset/Unstable/After\render_517_after.png
# Processing: Test_Dataset/Unstable/Before\render_520_before.png and Test_Dataset/Unstable/After\render_520_after.png
# Processing: Test_Dataset/Unstable/Before\render_522_before.png and Test_Dataset/Unstable/After\render_522_after.png
# Processing: Test_Dataset/Unstable/Before\render_523_before.png and Test_Dataset/Unstable/After\render_523_after.png
# Processing: Test_Dataset/Unstable/Before\render_525_before.png and Test_Dataset/Unstable/After\render_525_after.png
# Processing: Test_Dataset/Unstable/Before\render_527_before.png and Test_Dataset/Unstable/After\render_527_after.png
# Processing: Test_Dataset/Unstable/Before\render_531_before.png and Test_Dataset/Unstable/After\render_531_after.png
# Processing: Test_Dataset/Unstable/Before\render_532_before.png and Test_Dataset/Unstable/After\render_532_after.png
# Processing: Test_Dataset/Unstable/Before\render_533_before.png and Test_Dataset/Unstable/After\render_533_after.png
# Processing: Test_Dataset/Unstable/Before\render_534_before.png and Test_Dataset/Unstable/After\render_534_after.png
# Processing: Test_Dataset/Unstable/Before\render_535_before.png and Test_Dataset/Unstable/After\render_535_after.png
# Processing: Test_Dataset/Unstable/Before\render_539_before.png and Test_Dataset/Unstable/After\render_539_after.png
# Processing: Test_Dataset/Unstable/Before\render_53_before.png and Test_Dataset/Unstable/After\render_53_after.png
# Processing: Test_Dataset/Unstable/Before\render_540_before.png and Test_Dataset/Unstable/After\render_540_after.png
# Processing: Test_Dataset/Unstable/Before\render_542_before.png and Test_Dataset/Unstable/After\render_542_after.png
# Processing: Test_Dataset/Unstable/Before\render_543_before.png and Test_Dataset/Unstable/After\render_543_after.png
# Processing: Test_Dataset/Unstable/Before\render_545_before.png and Test_Dataset/Unstable/After\render_545_after.png
# Processing: Test_Dataset/Unstable/Before\render_546_before.png and Test_Dataset/Unstable/After\render_546_after.png
# Processing: Test_Dataset/Unstable/Before\render_547_before.png and Test_Dataset/Unstable/After\render_547_after.png
# Processing: Test_Dataset/Unstable/Before\render_548_before.png and Test_Dataset/Unstable/After\render_548_after.png
# Processing: Test_Dataset/Unstable/Before\render_549_before.png and Test_Dataset/Unstable/After\render_549_after.png
# Processing: Test_Dataset/Unstable/Before\render_54_before.png and Test_Dataset/Unstable/After\render_54_after.png
# Processing: Test_Dataset/Unstable/Before\render_550_before.png and Test_Dataset/Unstable/After\render_550_after.png
# Processing: Test_Dataset/Unstable/Before\render_551_before.png and Test_Dataset/Unstable/After\render_551_after.png
# Processing: Test_Dataset/Unstable/Before\render_552_before.png and Test_Dataset/Unstable/After\render_552_after.png
# Processing: Test_Dataset/Unstable/Before\render_555_before.png and Test_Dataset/Unstable/After\render_555_after.png
# Processing: Test_Dataset/Unstable/Before\render_556_before.png and Test_Dataset/Unstable/After\render_556_after.png
# Processing: Test_Dataset/Unstable/Before\render_558_before.png and Test_Dataset/Unstable/After\render_558_after.png
# Processing: Test_Dataset/Unstable/Before\render_559_before.png and Test_Dataset/Unstable/After\render_559_after.png
# Processing: Test_Dataset/Unstable/Before\render_55_before.png and Test_Dataset/Unstable/After\render_55_after.png
# Processing: Test_Dataset/Unstable/Before\render_560_before.png and Test_Dataset/Unstable/After\render_560_after.png
# Processing: Test_Dataset/Unstable/Before\render_561_before.png and Test_Dataset/Unstable/After\render_561_after.png
# Processing: Test_Dataset/Unstable/Before\render_562_before.png and Test_Dataset/Unstable/After\render_562_after.png
# Processing: Test_Dataset/Unstable/Before\render_563_before.png and Test_Dataset/Unstable/After\render_563_after.png
# Processing: Test_Dataset/Unstable/Before\render_564_before.png and Test_Dataset/Unstable/After\render_564_after.png
# Processing: Test_Dataset/Unstable/Before\render_566_before.png and Test_Dataset/Unstable/After\render_566_after.png
# Processing: Test_Dataset/Unstable/Before\render_567_before.png and Test_Dataset/Unstable/After\render_567_after.png
# Processing: Test_Dataset/Unstable/Before\render_569_before.png and Test_Dataset/Unstable/After\render_569_after.png
# Processing: Test_Dataset/Unstable/Before\render_570_before.png and Test_Dataset/Unstable/After\render_570_after.png
# Processing: Test_Dataset/Unstable/Before\render_571_before.png and Test_Dataset/Unstable/After\render_571_after.png
# Processing: Test_Dataset/Unstable/Before\render_575_before.png and Test_Dataset/Unstable/After\render_575_after.png
# Processing: Test_Dataset/Unstable/Before\render_576_before.png and Test_Dataset/Unstable/After\render_576_after.png
# Processing: Test_Dataset/Unstable/Before\render_577_before.png and Test_Dataset/Unstable/After\render_577_after.png
# Processing: Test_Dataset/Unstable/Before\render_578_before.png and Test_Dataset/Unstable/After\render_578_after.png
# Processing: Test_Dataset/Unstable/Before\render_579_before.png and Test_Dataset/Unstable/After\render_579_after.png
# Processing: Test_Dataset/Unstable/Before\render_583_before.png and Test_Dataset/Unstable/After\render_583_after.png
# Processing: Test_Dataset/Unstable/Before\render_585_before.png and Test_Dataset/Unstable/After\render_585_after.png
# Processing: Test_Dataset/Unstable/Before\render_587_before.png and Test_Dataset/Unstable/After\render_587_after.png
# Processing: Test_Dataset/Unstable/Before\render_589_before.png and Test_Dataset/Unstable/After\render_589_after.png
# Processing: Test_Dataset/Unstable/Before\render_590_before.png and Test_Dataset/Unstable/After\render_590_after.png
# Processing: Test_Dataset/Unstable/Before\render_591_before.png and Test_Dataset/Unstable/After\render_591_after.png
# Processing: Test_Dataset/Unstable/Before\render_595_before.png and Test_Dataset/Unstable/After\render_595_after.png
# Processing: Test_Dataset/Unstable/Before\render_596_before.png and Test_Dataset/Unstable/After\render_596_after.png
# Processing: Test_Dataset/Unstable/Before\render_597_before.png and Test_Dataset/Unstable/After\render_597_after.png
# Processing: Test_Dataset/Unstable/Before\render_598_before.png and Test_Dataset/Unstable/After\render_598_after.png
# Processing: Test_Dataset/Unstable/Before\render_599_before.png and Test_Dataset/Unstable/After\render_599_after.png
# Processing: Test_Dataset/Unstable/Before\render_59_before.png and Test_Dataset/Unstable/After\render_59_after.png
# Processing: Test_Dataset/Unstable/Before\render_600_before.png and Test_Dataset/Unstable/After\render_600_after.png
# Processing: Test_Dataset/Unstable/Before\render_601_before.png and Test_Dataset/Unstable/After\render_601_after.png
# Processing: Test_Dataset/Unstable/Before\render_602_before.png and Test_Dataset/Unstable/After\render_602_after.png
# Processing: Test_Dataset/Unstable/Before\render_603_before.png and Test_Dataset/Unstable/After\render_603_after.png
# Processing: Test_Dataset/Unstable/Before\render_604_before.png and Test_Dataset/Unstable/After\render_604_after.png
# Processing: Test_Dataset/Unstable/Before\render_606_before.png and Test_Dataset/Unstable/After\render_606_after.png
# Processing: Test_Dataset/Unstable/Before\render_607_before.png and Test_Dataset/Unstable/After\render_607_after.png
# Processing: Test_Dataset/Unstable/Before\render_60_before.png and Test_Dataset/Unstable/After\render_60_after.png
# Processing: Test_Dataset/Unstable/Before\render_610_before.png and Test_Dataset/Unstable/After\render_610_after.png
# Processing: Test_Dataset/Unstable/Before\render_613_before.png and Test_Dataset/Unstable/After\render_613_after.png
# Processing: Test_Dataset/Unstable/Before\render_614_before.png and Test_Dataset/Unstable/After\render_614_after.png
# Processing: Test_Dataset/Unstable/Before\render_615_before.png and Test_Dataset/Unstable/After\render_615_after.png
# Processing: Test_Dataset/Unstable/Before\render_616_before.png and Test_Dataset/Unstable/After\render_616_after.png
# Processing: Test_Dataset/Unstable/Before\render_617_before.png and Test_Dataset/Unstable/After\render_617_after.png
# Processing: Test_Dataset/Unstable/Before\render_619_before.png and Test_Dataset/Unstable/After\render_619_after.png
# Processing: Test_Dataset/Unstable/Before\render_620_before.png and Test_Dataset/Unstable/After\render_620_after.png
# Processing: Test_Dataset/Unstable/Before\render_621_before.png and Test_Dataset/Unstable/After\render_621_after.png
# Processing: Test_Dataset/Unstable/Before\render_623_before.png and Test_Dataset/Unstable/After\render_623_after.png
# Processing: Test_Dataset/Unstable/Before\render_626_before.png and Test_Dataset/Unstable/After\render_626_after.png
# Processing: Test_Dataset/Unstable/Before\render_627_before.png and Test_Dataset/Unstable/After\render_627_after.png
# Processing: Test_Dataset/Unstable/Before\render_628_before.png and Test_Dataset/Unstable/After\render_628_after.png
# Processing: Test_Dataset/Unstable/Before\render_62_before.png and Test_Dataset/Unstable/After\render_62_after.png
# Processing: Test_Dataset/Unstable/Before\render_632_before.png and Test_Dataset/Unstable/After\render_632_after.png
# Processing: Test_Dataset/Unstable/Before\render_633_before.png and Test_Dataset/Unstable/After\render_633_after.png
# Processing: Test_Dataset/Unstable/Before\render_634_before.png and Test_Dataset/Unstable/After\render_634_after.png
# Processing: Test_Dataset/Unstable/Before\render_635_before.png and Test_Dataset/Unstable/After\render_635_after.png
# Processing: Test_Dataset/Unstable/Before\render_637_before.png and Test_Dataset/Unstable/After\render_637_after.png
# Processing: Test_Dataset/Unstable/Before\render_639_before.png and Test_Dataset/Unstable/After\render_639_after.png
# Processing: Test_Dataset/Unstable/Before\render_63_before.png and Test_Dataset/Unstable/After\render_63_after.png
# Processing: Test_Dataset/Unstable/Before\render_640_before.png and Test_Dataset/Unstable/After\render_640_after.png
# Processing: Test_Dataset/Unstable/Before\render_641_before.png and Test_Dataset/Unstable/After\render_641_after.png
# Processing: Test_Dataset/Unstable/Before\render_645_before.png and Test_Dataset/Unstable/After\render_645_after.png
# Processing: Test_Dataset/Unstable/Before\render_646_before.png and Test_Dataset/Unstable/After\render_646_after.png
# Processing: Test_Dataset/Unstable/Before\render_647_before.png and Test_Dataset/Unstable/After\render_647_after.png
# Processing: Test_Dataset/Unstable/Before\render_648_before.png and Test_Dataset/Unstable/After\render_648_after.png
# Processing: Test_Dataset/Unstable/Before\render_64_before.png and Test_Dataset/Unstable/After\render_64_after.png
# Processing: Test_Dataset/Unstable/Before\render_650_before.png and Test_Dataset/Unstable/After\render_650_after.png
# Processing: Test_Dataset/Unstable/Before\render_651_before.png and Test_Dataset/Unstable/After\render_651_after.png
# Processing: Test_Dataset/Unstable/Before\render_652_before.png and Test_Dataset/Unstable/After\render_652_after.png
# Processing: Test_Dataset/Unstable/Before\render_653_before.png and Test_Dataset/Unstable/After\render_653_after.png
# Processing: Test_Dataset/Unstable/Before\render_654_before.png and Test_Dataset/Unstable/After\render_654_after.png
# Processing: Test_Dataset/Unstable/Before\render_656_before.png and Test_Dataset/Unstable/After\render_656_after.png
# Processing: Test_Dataset/Unstable/Before\render_657_before.png and Test_Dataset/Unstable/After\render_657_after.png
# Processing: Test_Dataset/Unstable/Before\render_658_before.png and Test_Dataset/Unstable/After\render_658_after.png
# Processing: Test_Dataset/Unstable/Before\render_659_before.png and Test_Dataset/Unstable/After\render_659_after.png
# Processing: Test_Dataset/Unstable/Before\render_65_before.png and Test_Dataset/Unstable/After\render_65_after.png
# Processing: Test_Dataset/Unstable/Before\render_660_before.png and Test_Dataset/Unstable/After\render_660_after.png
# Processing: Test_Dataset/Unstable/Before\render_661_before.png and Test_Dataset/Unstable/After\render_661_after.png
# Processing: Test_Dataset/Unstable/Before\render_662_before.png and Test_Dataset/Unstable/After\render_662_after.png
# Processing: Test_Dataset/Unstable/Before\render_664_before.png and Test_Dataset/Unstable/After\render_664_after.png
# Processing: Test_Dataset/Unstable/Before\render_666_before.png and Test_Dataset/Unstable/After\render_666_after.png
# Processing: Test_Dataset/Unstable/Before\render_669_before.png and Test_Dataset/Unstable/After\render_669_after.png
# Processing: Test_Dataset/Unstable/Before\render_670_before.png and Test_Dataset/Unstable/After\render_670_after.png
# Processing: Test_Dataset/Unstable/Before\render_671_before.png and Test_Dataset/Unstable/After\render_671_after.png
# Processing: Test_Dataset/Unstable/Before\render_674_before.png and Test_Dataset/Unstable/After\render_674_after.png
# Processing: Test_Dataset/Unstable/Before\render_675_before.png and Test_Dataset/Unstable/After\render_675_after.png
# Processing: Test_Dataset/Unstable/Before\render_676_before.png and Test_Dataset/Unstable/After\render_676_after.png
# Processing: Test_Dataset/Unstable/Before\render_677_before.png and Test_Dataset/Unstable/After\render_677_after.png
# Processing: Test_Dataset/Unstable/Before\render_678_before.png and Test_Dataset/Unstable/After\render_678_after.png
# Processing: Test_Dataset/Unstable/Before\render_679_before.png and Test_Dataset/Unstable/After\render_679_after.png
# Processing: Test_Dataset/Unstable/Before\render_680_before.png and Test_Dataset/Unstable/After\render_680_after.png
# Processing: Test_Dataset/Unstable/Before\render_681_before.png and Test_Dataset/Unstable/After\render_681_after.png
# Processing: Test_Dataset/Unstable/Before\render_686_before.png and Test_Dataset/Unstable/After\render_686_after.png
# Processing: Test_Dataset/Unstable/Before\render_687_before.png and Test_Dataset/Unstable/After\render_687_after.png
# Processing: Test_Dataset/Unstable/Before\render_689_before.png and Test_Dataset/Unstable/After\render_689_after.png
# Processing: Test_Dataset/Unstable/Before\render_68_before.png and Test_Dataset/Unstable/After\render_68_after.png
# Processing: Test_Dataset/Unstable/Before\render_690_before.png and Test_Dataset/Unstable/After\render_690_after.png
# Processing: Test_Dataset/Unstable/Before\render_692_before.png and Test_Dataset/Unstable/After\render_692_after.png
# Processing: Test_Dataset/Unstable/Before\render_693_before.png and Test_Dataset/Unstable/After\render_693_after.png
# Processing: Test_Dataset/Unstable/Before\render_694_before.png and Test_Dataset/Unstable/After\render_694_after.png
# Processing: Test_Dataset/Unstable/Before\render_695_before.png and Test_Dataset/Unstable/After\render_695_after.png
# Processing: Test_Dataset/Unstable/Before\render_697_before.png and Test_Dataset/Unstable/After\render_697_after.png
# Processing: Test_Dataset/Unstable/Before\render_699_before.png and Test_Dataset/Unstable/After\render_699_after.png
# Processing: Test_Dataset/Unstable/Before\render_700_before.png and Test_Dataset/Unstable/After\render_700_after.png
# Processing: Test_Dataset/Unstable/Before\render_701_before.png and Test_Dataset/Unstable/After\render_701_after.png
# Processing: Test_Dataset/Unstable/Before\render_702_before.png and Test_Dataset/Unstable/After\render_702_after.png
# Processing: Test_Dataset/Unstable/Before\render_704_before.png and Test_Dataset/Unstable/After\render_704_after.png
# Processing: Test_Dataset/Unstable/Before\render_705_before.png and Test_Dataset/Unstable/After\render_705_after.png
# Processing: Test_Dataset/Unstable/Before\render_707_before.png and Test_Dataset/Unstable/After\render_707_after.png
# Processing: Test_Dataset/Unstable/Before\render_709_before.png and Test_Dataset/Unstable/After\render_709_after.png
# Processing: Test_Dataset/Unstable/Before\render_70_before.png and Test_Dataset/Unstable/After\render_70_after.png
# Processing: Test_Dataset/Unstable/Before\render_710_before.png and Test_Dataset/Unstable/After\render_710_after.png
# Processing: Test_Dataset/Unstable/Before\render_713_before.png and Test_Dataset/Unstable/After\render_713_after.png
# Processing: Test_Dataset/Unstable/Before\render_714_before.png and Test_Dataset/Unstable/After\render_714_after.png
# Processing: Test_Dataset/Unstable/Before\render_716_before.png and Test_Dataset/Unstable/After\render_716_after.png
# Processing: Test_Dataset/Unstable/Before\render_717_before.png and Test_Dataset/Unstable/After\render_717_after.png
# Processing: Test_Dataset/Unstable/Before\render_719_before.png and Test_Dataset/Unstable/After\render_719_after.png
# Processing: Test_Dataset/Unstable/Before\render_71_before.png and Test_Dataset/Unstable/After\render_71_after.png
# Processing: Test_Dataset/Unstable/Before\render_720_before.png and Test_Dataset/Unstable/After\render_720_after.png
# Processing: Test_Dataset/Unstable/Before\render_721_before.png and Test_Dataset/Unstable/After\render_721_after.png
# Processing: Test_Dataset/Unstable/Before\render_722_before.png and Test_Dataset/Unstable/After\render_722_after.png
# Processing: Test_Dataset/Unstable/Before\render_723_before.png and Test_Dataset/Unstable/After\render_723_after.png
# Processing: Test_Dataset/Unstable/Before\render_724_before.png and Test_Dataset/Unstable/After\render_724_after.png
# Processing: Test_Dataset/Unstable/Before\render_725_before.png and Test_Dataset/Unstable/After\render_725_after.png
# Processing: Test_Dataset/Unstable/Before\render_727_before.png and Test_Dataset/Unstable/After\render_727_after.png
# Processing: Test_Dataset/Unstable/Before\render_728_before.png and Test_Dataset/Unstable/After\render_728_after.png
# Processing: Test_Dataset/Unstable/Before\render_732_before.png and Test_Dataset/Unstable/After\render_732_after.png
# Processing: Test_Dataset/Unstable/Before\render_734_before.png and Test_Dataset/Unstable/After\render_734_after.png
# Processing: Test_Dataset/Unstable/Before\render_735_before.png and Test_Dataset/Unstable/After\render_735_after.png
# Processing: Test_Dataset/Unstable/Before\render_737_before.png and Test_Dataset/Unstable/After\render_737_after.png
# Processing: Test_Dataset/Unstable/Before\render_741_before.png and Test_Dataset/Unstable/After\render_741_after.png
# Processing: Test_Dataset/Unstable/Before\render_742_before.png and Test_Dataset/Unstable/After\render_742_after.png
# Processing: Test_Dataset/Unstable/Before\render_743_before.png and Test_Dataset/Unstable/After\render_743_after.png
# Processing: Test_Dataset/Unstable/Before\render_745_before.png and Test_Dataset/Unstable/After\render_745_after.png
# Processing: Test_Dataset/Unstable/Before\render_746_before.png and Test_Dataset/Unstable/After\render_746_after.png
# Processing: Test_Dataset/Unstable/Before\render_748_before.png and Test_Dataset/Unstable/After\render_748_after.png
# Processing: Test_Dataset/Unstable/Before\render_749_before.png and Test_Dataset/Unstable/After\render_749_after.png
# Processing: Test_Dataset/Unstable/Before\render_74_before.png and Test_Dataset/Unstable/After\render_74_after.png
# Processing: Test_Dataset/Unstable/Before\render_750_before.png and Test_Dataset/Unstable/After\render_750_after.png
# Processing: Test_Dataset/Unstable/Before\render_752_before.png and Test_Dataset/Unstable/After\render_752_after.png
# Processing: Test_Dataset/Unstable/Before\render_753_before.png and Test_Dataset/Unstable/After\render_753_after.png
# Processing: Test_Dataset/Unstable/Before\render_755_before.png and Test_Dataset/Unstable/After\render_755_after.png
# Processing: Test_Dataset/Unstable/Before\render_757_before.png and Test_Dataset/Unstable/After\render_757_after.png
# Processing: Test_Dataset/Unstable/Before\render_75_before.png and Test_Dataset/Unstable/After\render_75_after.png
# Processing: Test_Dataset/Unstable/Before\render_760_before.png and Test_Dataset/Unstable/After\render_760_after.png
# Processing: Test_Dataset/Unstable/Before\render_762_before.png and Test_Dataset/Unstable/After\render_762_after.png
# Processing: Test_Dataset/Unstable/Before\render_763_before.png and Test_Dataset/Unstable/After\render_763_after.png
# Processing: Test_Dataset/Unstable/Before\render_766_before.png and Test_Dataset/Unstable/After\render_766_after.png
# Processing: Test_Dataset/Unstable/Before\render_769_before.png and Test_Dataset/Unstable/After\render_769_after.png
# Processing: Test_Dataset/Unstable/Before\render_770_before.png and Test_Dataset/Unstable/After\render_770_after.png
# Processing: Test_Dataset/Unstable/Before\render_772_before.png and Test_Dataset/Unstable/After\render_772_after.png
# Processing: Test_Dataset/Unstable/Before\render_774_before.png and Test_Dataset/Unstable/After\render_774_after.png
# Processing: Test_Dataset/Unstable/Before\render_775_before.png and Test_Dataset/Unstable/After\render_775_after.png
# Processing: Test_Dataset/Unstable/Before\render_776_before.png and Test_Dataset/Unstable/After\render_776_after.png
# Processing: Test_Dataset/Unstable/Before\render_778_before.png and Test_Dataset/Unstable/After\render_778_after.png
# Processing: Test_Dataset/Unstable/Before\render_77_before.png and Test_Dataset/Unstable/After\render_77_after.png
# Processing: Test_Dataset/Unstable/Before\render_782_before.png and Test_Dataset/Unstable/After\render_782_after.png
# Processing: Test_Dataset/Unstable/Before\render_783_before.png and Test_Dataset/Unstable/After\render_783_after.png
# Processing: Test_Dataset/Unstable/Before\render_784_before.png and Test_Dataset/Unstable/After\render_784_after.png
# Processing: Test_Dataset/Unstable/Before\render_785_before.png and Test_Dataset/Unstable/After\render_785_after.png
# Processing: Test_Dataset/Unstable/Before\render_786_before.png and Test_Dataset/Unstable/After\render_786_after.png
# Processing: Test_Dataset/Unstable/Before\render_787_before.png and Test_Dataset/Unstable/After\render_787_after.png
# Processing: Test_Dataset/Unstable/Before\render_788_before.png and Test_Dataset/Unstable/After\render_788_after.png
# Processing: Test_Dataset/Unstable/Before\render_790_before.png and Test_Dataset/Unstable/After\render_790_after.png
# Processing: Test_Dataset/Unstable/Before\render_791_before.png and Test_Dataset/Unstable/After\render_791_after.png
# Processing: Test_Dataset/Unstable/Before\render_795_before.png and Test_Dataset/Unstable/After\render_795_after.png
# Processing: Test_Dataset/Unstable/Before\render_796_before.png and Test_Dataset/Unstable/After\render_796_after.png
# Processing: Test_Dataset/Unstable/Before\render_797_before.png and Test_Dataset/Unstable/After\render_797_after.png
# Processing: Test_Dataset/Unstable/Before\render_798_before.png and Test_Dataset/Unstable/After\render_798_after.png
# Processing: Test_Dataset/Unstable/Before\render_799_before.png and Test_Dataset/Unstable/After\render_799_after.png
# Processing: Test_Dataset/Unstable/Before\render_79_before.png and Test_Dataset/Unstable/After\render_79_after.png
# Processing: Test_Dataset/Unstable/Before\render_800_before.png and Test_Dataset/Unstable/After\render_800_after.png
# Processing: Test_Dataset/Unstable/Before\render_801_before.png and Test_Dataset/Unstable/After\render_801_after.png
# Processing: Test_Dataset/Unstable/Before\render_803_before.png and Test_Dataset/Unstable/After\render_803_after.png
# Processing: Test_Dataset/Unstable/Before\render_804_before.png and Test_Dataset/Unstable/After\render_804_after.png
# Processing: Test_Dataset/Unstable/Before\render_805_before.png and Test_Dataset/Unstable/After\render_805_after.png
# Processing: Test_Dataset/Unstable/Before\render_806_before.png and Test_Dataset/Unstable/After\render_806_after.png
# Processing: Test_Dataset/Unstable/Before\render_807_before.png and Test_Dataset/Unstable/After\render_807_after.png
# Processing: Test_Dataset/Unstable/Before\render_808_before.png and Test_Dataset/Unstable/After\render_808_after.png
# Processing: Test_Dataset/Unstable/Before\render_809_before.png and Test_Dataset/Unstable/After\render_809_after.png
# Processing: Test_Dataset/Unstable/Before\render_810_before.png and Test_Dataset/Unstable/After\render_810_after.png
# Processing: Test_Dataset/Unstable/Before\render_812_before.png and Test_Dataset/Unstable/After\render_812_after.png
# Processing: Test_Dataset/Unstable/Before\render_813_before.png and Test_Dataset/Unstable/After\render_813_after.png
# All optical flow masks have been processed and saved.
